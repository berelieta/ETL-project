# %%
#Dependencies
import pymongo
import pandas as pd
import numpy as np

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
#Read index file
index_file = "resources/index.csv"
index_df = pd.read_csv(index_file)
index_df.head()
# Out:
#    Unnamed: 0                 path  class_id train-valid
# 0           0  marvel/0001/001.jpg         1       train
# 1           1  marvel/0001/002.jpg         1       valid
# 2           2  marvel/0001/003.jpg         1       train
# 3           3  marvel/0001/004.jpg         1       train
# 4           4  marvel/0001/005.jpg         1       train

# %%
#Read metadata file
metadata_file = "resources/metadata.csv"
metadata_df = pd.read_csv(metadata_file)
metadata_df.head()
# Out:
#    Unnamed: 0  class_id lego_ids                 lego_names minifigure_name
# 0           0         1  [76115]  ['Spider Mech vs. Venom']      SPIDER-MAN
# 1           1         2  [76115]  ['Spider Mech vs. Venom']           VENOM
# 2           2         3  [76115]  ['Spider Mech vs. Venom']        AUNT MAY
# 3           3         4  [76115]  ['Spider Mech vs. Venom']    GHOST SPIDER
# 4           4         5  [75208]             ["Yoda's Hut"]            YODA

# %%
# Clean data
metadata_df['lego_ids'] = metadata_df.apply(lambda x: x['lego_ids'].replace('[', '').replace(']', ''),axis=1)
metadata_df.head()
# Out:
#    Unnamed: 0  class_id lego_ids                 lego_names minifigure_name
# 0           0         1    76115  ['Spider Mech vs. Venom']      SPIDER-MAN
# 1           1         2    76115  ['Spider Mech vs. Venom']           VENOM
# 2           2         3    76115  ['Spider Mech vs. Venom']        AUNT MAY
# 3           3         4    76115  ['Spider Mech vs. Venom']    GHOST SPIDER
# 4           4         5    75208             ["Yoda's Hut"]            YODA

# %%
# Clean data
metadata_df['lego_names'] = metadata_df.apply(lambda x: x['lego_names'].replace('[', '').replace(']', '').replace("'", "").replace('"', ""),axis=1)
metadata_df.head()
# Out:
#    Unnamed: 0  class_id lego_ids             lego_names minifigure_name
# 0           0         1    76115  Spider Mech vs. Venom      SPIDER-MAN
# 1           1         2    76115  Spider Mech vs. Venom           VENOM
# 2           2         3    76115  Spider Mech vs. Venom        AUNT MAY
# 3           3         4    76115  Spider Mech vs. Venom    GHOST SPIDER
# 4           4         5    75208              Yodas Hut            YODA

# %% [markdown]
# # Transform dataFrames

# %%
index_cols = ["Unnamed: 0", "path", "class_id"]
index_transformed = index_df[index_cols].copy()
# Rename the column headers
index_transformed = index_transformed.rename(columns={"Unnamed: 0": "image_id",
                                                      "path": "image_path"})
# Set index
#index_transformed.set_index("image_id", inplace=True)
index_transformed.head()
# Out:
#    image_id           image_path  class_id
# 0         0  marvel/0001/001.jpg         1
# 1         1  marvel/0001/002.jpg         1
# 2         2  marvel/0001/003.jpg         1
# 3         3  marvel/0001/004.jpg         1
# 4         4  marvel/0001/005.jpg         1

# %%
metadata_cols = ["class_id", "lego_ids", "lego_names", "minifigure_name"]
metadata_transformed = metadata_df[metadata_cols].copy()
# Rename the column headers
metadata_transformed = metadata_transformed.rename(columns={"lego_ids": "lego_id",
                                                            "lego_names": "lego_name"})
# Set index
#metadata_transformed.set_index("class_id", inplace=True)
metadata_transformed.head()
# Out:
#    class_id lego_id              lego_name minifigure_name
# 0         1   76115  Spider Mech vs. Venom      SPIDER-MAN
# 1         2   76115  Spider Mech vs. Venom           VENOM
# 2         3   76115  Spider Mech vs. Venom        AUNT MAY
# 3         4   76115  Spider Mech vs. Venom    GHOST SPIDER
# 4         5   75208              Yodas Hut            YODA

# %% [markdown]
# # Create database connection

# %%
# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.legoDB
legoCT = db.legoCT
legoIMG = db.legoIMG

# %%
db.legoCT.drop()
db.legoIMG.drop()

# %% [markdown]
# # Load DataFrames into database

# %%
legoCT.insert_many(metadata_transformed.to_dict('records'))

# %%
legoIMG.insert_many(index_transformed.to_dict('records'))

# %%
collection = legoCT.find({'minifigure_name': 'SPIDER-MAN'})

# %%
for i in lego_images:
    print(i)
# Out:
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5bd'), 'image_id': 0, 'image_path': 'marvel/0001/001.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5be'), 'image_id': 1, 'image_path': 'marvel/0001/002.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5bf'), 'image_id': 2, 'image_path': 'marvel/0001/003.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c0'), 'image_id': 3, 'image_path': 'marvel/0001/004.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c1'), 'image_id': 4, 'image_path': 'marvel/0001/005.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c2'), 'image_id': 5, 'image_path': 'marvel/0001/006.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c3'), 'image_id': 6, 'image_path': 'marvel/0001/007.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c4'), 'image_id': 7, 'image_path': 'marvel/0001/008.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c5'), 'image_id': 8, 'image_path': 'marvel/0001/009.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c6'), 'image_id': 9, 'image_path': 'marvel/0001/010.jpg', 'class_id': 1}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c7'), 'image_id': 10, 'image_path': 'marvel/0002/001.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c8'), 'image_id': 11, 'image_path': 'marvel/0002/002.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5c9'), 'image_id': 12, 'image_path': 'marvel/0002/003.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ca'), 'image_id': 13, 'image_path': 'marvel/0002/004.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5cb'), 'image_id': 14, 'image_path': 'marvel/0002/005.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5cc'), 'image_id': 15, 'image_path': 'marvel/0002/006.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5cd'), 'image_id': 16, 'image_path': 'marvel/0002/007.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ce'), 'image_id': 17, 'image_path': 'marvel/0002/008.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5cf'), 'image_id': 18, 'image_path': 'marvel/0002/009.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d0'), 'image_id': 19, 'image_path': 'marvel/0002/010.jpg', 'class_id': 2}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d1'), 'image_id': 20, 'image_path': 'marvel/0003/001.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d2'), 'image_id': 21, 'image_path': 'marvel/0003/002.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d3'), 'image_id': 22, 'image_path': 'marvel/0003/003.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d4'), 'image_id': 23, 'image_path': 'marvel/0003/004.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d5'), 'image_id': 24, 'image_path': 'marvel/0003/005.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d6'), 'image_id': 25, 'image_path': 'marvel/0003/006.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d7'), 'image_id': 26, 'image_path': 'marvel/0003/007.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d8'), 'image_id': 27, 'image_path': 'marvel/0003/008.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5d9'), 'image_id': 28, 'image_path': 'marvel/0003/009.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5da'), 'image_id': 29, 'image_path': 'marvel/0003/010.jpg', 'class_id': 3}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5db'), 'image_id': 30, 'image_path': 'marvel/0004/001.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5dc'), 'image_id': 31, 'image_path': 'marvel/0004/002.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5dd'), 'image_id': 32, 'image_path': 'marvel/0004/003.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5de'), 'image_id': 33, 'image_path': 'marvel/0004/004.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5df'), 'image_id': 34, 'image_path': 'marvel/0004/005.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e0'), 'image_id': 35, 'image_path': 'marvel/0004/006.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e1'), 'image_id': 36, 'image_path': 'marvel/0004/007.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e2'), 'image_id': 37, 'image_path': 'marvel/0004/008.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e3'), 'image_id': 38, 'image_path': 'marvel/0004/009.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e4'), 'image_id': 39, 'image_path': 'marvel/0004/010.jpg', 'class_id': 4}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e5'), 'image_id': 40, 'image_path': 'star-wars/0001/001.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e6'), 'image_id': 41, 'image_path': 'star-wars/0001/002.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e7'), 'image_id': 42, 'image_path': 'star-wars/0001/003.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e8'), 'image_id': 43, 'image_path': 'star-wars/0001/004.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5e9'), 'image_id': 44, 'image_path': 'star-wars/0001/005.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ea'), 'image_id': 45, 'image_path': 'star-wars/0001/006.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5eb'), 'image_id': 46, 'image_path': 'star-wars/0001/007.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ec'), 'image_id': 47, 'image_path': 'star-wars/0001/008.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ed'), 'image_id': 48, 'image_path': 'star-wars/0001/009.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ee'), 'image_id': 49, 'image_path': 'star-wars/0001/010.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ef'), 'image_id': 50, 'image_path': 'star-wars/0001/011.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f0'), 'image_id': 51, 'image_path': 'star-wars/0002/001.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f1'), 'image_id': 52, 'image_path': 'star-wars/0002/002.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f2'), 'image_id': 53, 'image_path': 'star-wars/0002/003.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f3'), 'image_id': 54, 'image_path': 'star-wars/0002/004.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f4'), 'image_id': 55, 'image_path': 'star-wars/0002/005.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f5'), 'image_id': 56, 'image_path': 'star-wars/0002/006.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f6'), 'image_id': 57, 'image_path': 'star-wars/0002/007.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f7'), 'image_id': 58, 'image_path': 'star-wars/0002/008.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f8'), 'image_id': 59, 'image_path': 'star-wars/0002/009.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5f9'), 'image_id': 60, 'image_path': 'star-wars/0002/010.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5fa'), 'image_id': 61, 'image_path': 'star-wars/0002/011.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5fb'), 'image_id': 62, 'image_path': 'star-wars/0003/001.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5fc'), 'image_id': 63, 'image_path': 'star-wars/0003/002.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5fd'), 'image_id': 64, 'image_path': 'star-wars/0003/003.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5fe'), 'image_id': 65, 'image_path': 'star-wars/0003/004.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a5ff'), 'image_id': 66, 'image_path': 'star-wars/0003/005.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a600'), 'image_id': 67, 'image_path': 'star-wars/0003/006.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a601'), 'image_id': 68, 'image_path': 'star-wars/0003/007.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a602'), 'image_id': 69, 'image_path': 'star-wars/0003/008.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a603'), 'image_id': 70, 'image_path': 'star-wars/0003/009.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a604'), 'image_id': 71, 'image_path': 'star-wars/0003/010.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a605'), 'image_id': 72, 'image_path': 'star-wars/0003/011.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a606'), 'image_id': 73, 'image_path': 'star-wars/0004/001.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a607'), 'image_id': 74, 'image_path': 'star-wars/0004/002.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a608'), 'image_id': 75, 'image_path': 'star-wars/0004/003.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a609'), 'image_id': 76, 'image_path': 'star-wars/0005/001.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a60a'), 'image_id': 77, 'image_path': 'star-wars/0005/002.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a60b'), 'image_id': 78, 'image_path': 'star-wars/0005/003.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a60c'), 'image_id': 79, 'image_path': 'star-wars/0001/012.jpg', 'class_id': 5}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a60d'), 'image_id': 80, 'image_path': 'star-wars/0002/012.jpg', 'class_id': 6}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a60e'), 'image_id': 81, 'image_path': 'star-wars/0003/012.jpg', 'class_id': 7}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a60f'), 'image_id': 82, 'image_path': 'star-wars/0006/001.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a610'), 'image_id': 83, 'image_path': 'star-wars/0006/002.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a611'), 'image_id': 84, 'image_path': 'star-wars/0006/003.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a612'), 'image_id': 85, 'image_path': 'star-wars/0004/004.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a613'), 'image_id': 86, 'image_path': 'star-wars/0004/005.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a614'), 'image_id': 87, 'image_path': 'star-wars/0004/006.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a615'), 'image_id': 88, 'image_path': 'star-wars/0004/007.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a616'), 'image_id': 89, 'image_path': 'star-wars/0004/008.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a617'), 'image_id': 90, 'image_path': 'star-wars/0004/009.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a618'), 'image_id': 91, 'image_path': 'star-wars/0004/010.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a619'), 'image_id': 92, 'image_path': 'star-wars/0004/011.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a61a'), 'image_id': 93, 'image_path': 'star-wars/0004/012.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a61b'), 'image_id': 94, 'image_path': 'star-wars/0004/013.jpg', 'class_id': 8}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a61c'), 'image_id': 95, 'image_path': 'star-wars/0005/004.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a61d'), 'image_id': 96, 'image_path': 'star-wars/0005/005.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a61e'), 'image_id': 97, 'image_path': 'star-wars/0005/006.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a61f'), 'image_id': 98, 'image_path': 'star-wars/0005/007.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a620'), 'image_id': 99, 'image_path': 'star-wars/0005/008.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a621'), 'image_id': 100, 'image_path': 'star-wars/0005/009.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a622'), 'image_id': 101, 'image_path': 'star-wars/0005/010.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a623'), 'image_id': 102, 'image_path': 'star-wars/0005/011.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a624'), 'image_id': 103, 'image_path': 'star-wars/0005/012.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a625'), 'image_id': 104, 'image_path': 'star-wars/0005/013.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a626'), 'image_id': 105, 'image_path': 'star-wars/0005/014.jpg', 'class_id': 9}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a627'), 'image_id': 106, 'image_path': 'star-wars/0006/004.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a628'), 'image_id': 107, 'image_path': 'star-wars/0006/005.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a629'), 'image_id': 108, 'image_path': 'star-wars/0006/006.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a62a'), 'image_id': 109, 'image_path': 'star-wars/0006/007.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a62b'), 'image_id': 110, 'image_path': 'star-wars/0006/008.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a62c'), 'image_id': 111, 'image_path': 'star-wars/0006/009.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a62d'), 'image_id': 112, 'image_path': 'star-wars/0006/010.jpg', 'class_id': 10}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a62e'), 'image_id': 113, 'image_path': 'star-wars/0007/001.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a62f'), 'image_id': 114, 'image_path': 'star-wars/0007/002.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a630'), 'image_id': 115, 'image_path': 'star-wars/0007/003.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a631'), 'image_id': 116, 'image_path': 'star-wars/0007/004.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a632'), 'image_id': 117, 'image_path': 'star-wars/0007/005.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a633'), 'image_id': 118, 'image_path': 'star-wars/0007/006.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a634'), 'image_id': 119, 'image_path': 'star-wars/0007/007.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a635'), 'image_id': 120, 'image_path': 'star-wars/0008/001.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a636'), 'image_id': 121, 'image_path': 'star-wars/0008/002.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a637'), 'image_id': 122, 'image_path': 'star-wars/0008/003.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a638'), 'image_id': 123, 'image_path': 'star-wars/0008/004.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a639'), 'image_id': 124, 'image_path': 'star-wars/0008/005.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a63a'), 'image_id': 125, 'image_path': 'star-wars/0008/006.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a63b'), 'image_id': 126, 'image_path': 'star-wars/0008/007.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a63c'), 'image_id': 127, 'image_path': 'star-wars/0009/001.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a63d'), 'image_id': 128, 'image_path': 'star-wars/0009/002.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a63e'), 'image_id': 129, 'image_path': 'star-wars/0009/003.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a63f'), 'image_id': 130, 'image_path': 'star-wars/0009/004.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a640'), 'image_id': 131, 'image_path': 'star-wars/0009/005.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a641'), 'image_id': 132, 'image_path': 'star-wars/0009/006.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a642'), 'image_id': 133, 'image_path': 'star-wars/0009/007.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a643'), 'image_id': 134, 'image_path': 'star-wars/0010/001.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a644'), 'image_id': 135, 'image_path': 'star-wars/0010/002.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a645'), 'image_id': 136, 'image_path': 'star-wars/0010/003.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a646'), 'image_id': 137, 'image_path': 'star-wars/0010/004.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a647'), 'image_id': 138, 'image_path': 'star-wars/0010/005.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a648'), 'image_id': 139, 'image_path': 'star-wars/0010/006.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a649'), 'image_id': 140, 'image_path': 'star-wars/0010/007.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a64a'), 'image_id': 141, 'image_path': 'star-wars/0007/008.jpg', 'class_id': 11}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a64b'), 'image_id': 142, 'image_path': 'star-wars/0008/008.jpg', 'class_id': 12}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a64c'), 'image_id': 143, 'image_path': 'star-wars/0009/008.jpg', 'class_id': 13}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a64d'), 'image_id': 144, 'image_path': 'star-wars/0010/008.jpg', 'class_id': 14}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a64e'), 'image_id': 145, 'image_path': 'marvel/0005/001.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a64f'), 'image_id': 146, 'image_path': 'marvel/0005/002.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a650'), 'image_id': 147, 'image_path': 'marvel/0005/003.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a651'), 'image_id': 148, 'image_path': 'marvel/0005/004.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a652'), 'image_id': 149, 'image_path': 'marvel/0005/005.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a653'), 'image_id': 150, 'image_path': 'marvel/0005/006.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a654'), 'image_id': 151, 'image_path': 'marvel/0005/007.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a655'), 'image_id': 152, 'image_path': 'marvel/0005/008.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a656'), 'image_id': 153, 'image_path': 'marvel/0005/009.jpg', 'class_id': 15}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a657'), 'image_id': 154, 'image_path': 'marvel/0006/001.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a658'), 'image_id': 155, 'image_path': 'marvel/0006/002.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a659'), 'image_id': 156, 'image_path': 'marvel/0006/003.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a65a'), 'image_id': 157, 'image_path': 'marvel/0006/004.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a65b'), 'image_id': 158, 'image_path': 'marvel/0006/005.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a65c'), 'image_id': 159, 'image_path': 'marvel/0006/006.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a65d'), 'image_id': 160, 'image_path': 'marvel/0006/007.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a65e'), 'image_id': 161, 'image_path': 'marvel/0006/008.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a65f'), 'image_id': 162, 'image_path': 'marvel/0006/009.jpg', 'class_id': 16}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a660'), 'image_id': 163, 'image_path': 'marvel/0007/001.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a661'), 'image_id': 164, 'image_path': 'marvel/0007/002.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a662'), 'image_id': 165, 'image_path': 'marvel/0007/003.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a663'), 'image_id': 166, 'image_path': 'marvel/0007/004.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a664'), 'image_id': 167, 'image_path': 'marvel/0007/005.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a665'), 'image_id': 168, 'image_path': 'marvel/0007/006.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a666'), 'image_id': 169, 'image_path': 'marvel/0007/007.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a667'), 'image_id': 170, 'image_path': 'marvel/0007/008.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a668'), 'image_id': 171, 'image_path': 'marvel/0007/009.jpg', 'class_id': 17}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a669'), 'image_id': 172, 'image_path': 'harry-potter/0001/001.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a66a'), 'image_id': 173, 'image_path': 'harry-potter/0001/002.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a66b'), 'image_id': 174, 'image_path': 'harry-potter/0001/003.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a66c'), 'image_id': 175, 'image_path': 'harry-potter/0001/004.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a66d'), 'image_id': 176, 'image_path': 'harry-potter/0001/005.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a66e'), 'image_id': 177, 'image_path': 'harry-potter/0001/006.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a66f'), 'image_id': 178, 'image_path': 'harry-potter/0001/007.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a670'), 'image_id': 179, 'image_path': 'harry-potter/0001/008.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a671'), 'image_id': 180, 'image_path': 'harry-potter/0001/009.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a672'), 'image_id': 181, 'image_path': 'harry-potter/0001/010.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a673'), 'image_id': 182, 'image_path': 'harry-potter/0001/011.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a674'), 'image_id': 183, 'image_path': 'harry-potter/0001/012.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a675'), 'image_id': 184, 'image_path': 'harry-potter/0001/013.jpg', 'class_id': 18}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a676'), 'image_id': 185, 'image_path': 'harry-potter/0002/001.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a677'), 'image_id': 186, 'image_path': 'harry-potter/0002/002.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a678'), 'image_id': 187, 'image_path': 'harry-potter/0002/003.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a679'), 'image_id': 188, 'image_path': 'harry-potter/0002/004.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a67a'), 'image_id': 189, 'image_path': 'harry-potter/0002/005.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a67b'), 'image_id': 190, 'image_path': 'harry-potter/0002/006.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a67c'), 'image_id': 191, 'image_path': 'harry-potter/0002/007.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a67d'), 'image_id': 192, 'image_path': 'harry-potter/0002/008.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a67e'), 'image_id': 193, 'image_path': 'harry-potter/0002/009.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a67f'), 'image_id': 194, 'image_path': 'harry-potter/0002/010.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a680'), 'image_id': 195, 'image_path': 'harry-potter/0002/011.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a681'), 'image_id': 196, 'image_path': 'harry-potter/0002/012.jpg', 'class_id': 19}
# {'_id': ObjectId('5f598e7e19f4bbb655f0a682'), 'image_id': 197, 'image_path': 'harry-potter/0002/013.jpg', 'class_id': 19}

# %%
for i in legoCT.find({'minifigure_name': 'SPIDER-MAN'}):
    print(i)
# Out:
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5aa'), 'class_id': 1, 'lego_id': '76115', 'lego_name': 'Spider Mech vs. Venom', 'minifigure_name': 'SPIDER-MAN'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5ba'), 'class_id': 17, 'lego_id': '76128', 'lego_name': 'Molten Man Battle', 'minifigure_name': 'SPIDER-MAN'}

# %%
for i in legoCT.find({}):
    print(i)
# Out:
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5aa'), 'class_id': 1, 'lego_id': '76115', 'lego_name': 'Spider Mech vs. Venom', 'minifigure_name': 'SPIDER-MAN'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5ab'), 'class_id': 2, 'lego_id': '76115', 'lego_name': 'Spider Mech vs. Venom', 'minifigure_name': 'VENOM'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5ac'), 'class_id': 3, 'lego_id': '76115', 'lego_name': 'Spider Mech vs. Venom', 'minifigure_name': 'AUNT MAY'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5ad'), 'class_id': 4, 'lego_id': '76115', 'lego_name': 'Spider Mech vs. Venom', 'minifigure_name': 'GHOST SPIDER'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5ae'), 'class_id': 5, 'lego_id': '75208', 'lego_name': 'Yodas Hut', 'minifigure_name': 'YODA'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5af'), 'class_id': 6, 'lego_id': '75208', 'lego_name': 'Yodas Hut', 'minifigure_name': 'LUKE SKYWALKER'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b0'), 'class_id': 7, 'lego_id': '75208', 'lego_name': 'Yodas Hut', 'minifigure_name': 'R2-D2'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b1'), 'class_id': 8, 'lego_id': '75199', 'lego_name': 'General Grievous Combat Speeder', 'minifigure_name': 'MACE WINDU'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b2'), 'class_id': 9, 'lego_id': '75199', 'lego_name': 'General Grievous Combat Speeder', 'minifigure_name': 'GENERAL GRIEVOUS'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b3'), 'class_id': 10, 'lego_id': '75264', 'lego_name': 'Kylo Rens Shuttle Microfighter', 'minifigure_name': 'KYLO REN'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b4'), 'class_id': 11, 'lego_id': '75254', 'lego_name': 'AT-ST Raider from The Mandalorian', 'minifigure_name': 'THE MANDALORIAN'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b5'), 'class_id': 12, 'lego_id': '75254', 'lego_name': 'AT-ST Raider from The Mandalorian', 'minifigure_name': 'CARA DUNE'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b6'), 'class_id': 13, 'lego_id': '75254', 'lego_name': 'AT-ST Raider from The Mandalorian', 'minifigure_name': 'KLATOOINIAN RAIDER 1'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b7'), 'class_id': 14, 'lego_id': '75254', 'lego_name': 'AT-ST Raider from The Mandalorian', 'minifigure_name': 'KLATOOINIAN RAIDER 2'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b8'), 'class_id': 15, 'lego_id': '76128', 'lego_name': 'Molten Man Battle', 'minifigure_name': 'MYSTERIO'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5b9'), 'class_id': 16, 'lego_id': '76128', 'lego_name': 'Molten Man Battle', 'minifigure_name': 'FIREFIGHTER'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5ba'), 'class_id': 17, 'lego_id': '76128', 'lego_name': 'Molten Man Battle', 'minifigure_name': 'SPIDER-MAN'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5bb'), 'class_id': 18, 'lego_id': '75950', 'lego_name': 'Aragogs Lair', 'minifigure_name': 'Harry Potter'}
# {'_id': ObjectId('5f598e7c19f4bbb655f0a5bc'), 'class_id': 19, 'lego_id': '75950', 'lego_name': 'Aragogs Lair', 'minifigure_name': 'Ron Weasley'}
