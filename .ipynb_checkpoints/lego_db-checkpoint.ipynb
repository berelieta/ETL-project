# %%
#Dependencies
import pymongo
import pandas as pd
import numpy as np
# %pylab inline 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import pprint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
#Read index file
index_file = "resources/index.csv"
index_df = pd.read_csv(index_file)
index_df.head()
# Out:
#    Unnamed: 0                 path  class_id train-valid
# 0           0  marvel/0001/001.jpg         1       train
# 1           1  marvel/0001/002.jpg         1       valid
# 2           2  marvel/0001/003.jpg         1       train
# 3           3  marvel/0001/004.jpg         1       train
# 4           4  marvel/0001/005.jpg         1       train

# %%
#Read metadata file
metadata_file = "resources/metadata.csv"
metadata_df = pd.read_csv(metadata_file)
metadata_df.head()
# Out:
#    Unnamed: 0  class_id lego_ids                 lego_names minifigure_name
# 0           0         1  [76115]  ['Spider Mech vs. Venom']      SPIDER-MAN
# 1           1         2  [76115]  ['Spider Mech vs. Venom']           VENOM
# 2           2         3  [76115]  ['Spider Mech vs. Venom']        AUNT MAY
# 3           3         4  [76115]  ['Spider Mech vs. Venom']    GHOST SPIDER
# 4           4         5  [75208]             ["Yoda's Hut"]            YODA

# %%
# Clean data
metadata_df['lego_ids'] = metadata_df.apply(lambda x: x['lego_ids'].replace('[', '').replace(']', ''),axis=1)
metadata_df['lego_names'] = metadata_df.apply(lambda x: x['lego_names'].replace('[', '').replace(']', '').replace("'", "").replace('"', ""),axis=1)
metadata_df.head()
# Out:
#    Unnamed: 0  class_id lego_ids             lego_names minifigure_name
# 0           0         1    76115  Spider Mech vs. Venom      SPIDER-MAN
# 1           1         2    76115  Spider Mech vs. Venom           VENOM
# 2           2         3    76115  Spider Mech vs. Venom        AUNT MAY
# 3           3         4    76115  Spider Mech vs. Venom    GHOST SPIDER
# 4           4         5    75208              Yodas Hut            YODA

# %%
# Update paths for images
index_df['path'] = 'resources/' + index_df['path'].astype(str)
index_df.head()
# Out:
#    Unnamed: 0                           path  class_id train-valid
# 0           0  resources/marvel/0001/001.jpg         1       train
# 1           1  resources/marvel/0001/002.jpg         1       valid
# 2           2  resources/marvel/0001/003.jpg         1       train
# 3           3  resources/marvel/0001/004.jpg         1       train
# 4           4  resources/marvel/0001/005.jpg         1       train

# %% [markdown]
# # Transform dataFrames

# %%
index_cols = ["Unnamed: 0", "path", "class_id"]
index_transformed = index_df[index_cols].copy()
# Rename the column headers
index_transformed = index_transformed.rename(columns={"Unnamed: 0": "image_id",
                                                      "path": "image_path"})
# Set index
#index_transformed.set_index("image_id", inplace=True)
index_transformed.head()
# Out:
#    image_id                     image_path  class_id
# 0         0  resources/marvel/0001/001.jpg         1
# 1         1  resources/marvel/0001/002.jpg         1
# 2         2  resources/marvel/0001/003.jpg         1
# 3         3  resources/marvel/0001/004.jpg         1
# 4         4  resources/marvel/0001/005.jpg         1

# %%
metadata_cols = ["class_id", "lego_ids", "lego_names", "minifigure_name"]
metadata_transformed = metadata_df[metadata_cols].copy()
# Rename the column headers
metadata_transformed = metadata_transformed.rename(columns={"lego_ids": "lego_id",
                                                            "lego_names": "lego_name"})
# Set index
#metadata_transformed.set_index("class_id", inplace=True)
metadata_transformed.head()
# Out:
#    class_id lego_id              lego_name minifigure_name
# 0         1   76115  Spider Mech vs. Venom      SPIDER-MAN
# 1         2   76115  Spider Mech vs. Venom           VENOM
# 2         3   76115  Spider Mech vs. Venom        AUNT MAY
# 3         4   76115  Spider Mech vs. Venom    GHOST SPIDER
# 4         5   75208              Yodas Hut            YODA

# %% [markdown]
# # Create database connection

# %%
# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.legoDB
legoCT = db.legoCT
legoIMG = db.legoIMG

# %%
# Delete collections to avoid duplicate documents
db.legoCT.drop()
db.legoIMG.drop()

# %%
# Confirm the collection has been deleted
db.list_collection_names()
# Out:
# []

# %% [markdown]
# # Load DataFrames into database

# %%
legoCT.insert_many(metadata_transformed.to_dict('records'))

# %%
legoIMG.insert_many(index_transformed.to_dict('records'))

# %%
for lego in legoCT.find({}):
    pprint.pprint(lego)
# Out:
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60a'),
#  'class_id': 1,
#  'lego_id': '76115',
#  'lego_name': 'Spider Mech vs. Venom',
#  'minifigure_name': 'SPIDER-MAN'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60b'),
#  'class_id': 2,
#  'lego_id': '76115',
#  'lego_name': 'Spider Mech vs. Venom',
#  'minifigure_name': 'VENOM'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60c'),
#  'class_id': 3,
#  'lego_id': '76115',
#  'lego_name': 'Spider Mech vs. Venom',
#  'minifigure_name': 'AUNT MAY'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60d'),
#  'class_id': 4,
#  'lego_id': '76115',
#  'lego_name': 'Spider Mech vs. Venom',
#  'minifigure_name': 'GHOST SPIDER'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60e'),
#  'class_id': 5,
#  'lego_id': '75208',
#  'lego_name': 'Yodas Hut',
#  'minifigure_name': 'YODA'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60f'),
#  'class_id': 6,
#  'lego_id': '75208',
#  'lego_name': 'Yodas Hut',
#  'minifigure_name': 'LUKE SKYWALKER'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e610'),
#  'class_id': 7,
#  'lego_id': '75208',
#  'lego_name': 'Yodas Hut',
#  'minifigure_name': 'R2-D2'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e611'),
#  'class_id': 8,
#  'lego_id': '75199',
#  'lego_name': 'General Grievous Combat Speeder',
#  'minifigure_name': 'MACE WINDU'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e612'),
#  'class_id': 9,
#  'lego_id': '75199',
#  'lego_name': 'General Grievous Combat Speeder',
#  'minifigure_name': 'GENERAL GRIEVOUS'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e613'),
#  'class_id': 10,
#  'lego_id': '75264',
#  'lego_name': 'Kylo Rens Shuttle Microfighter',
#  'minifigure_name': 'KYLO REN'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e614'),
#  'class_id': 11,
#  'lego_id': '75254',
#  'lego_name': 'AT-ST Raider from The Mandalorian',
#  'minifigure_name': 'THE MANDALORIAN'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e615'),
#  'class_id': 12,
#  'lego_id': '75254',
#  'lego_name': 'AT-ST Raider from The Mandalorian',
#  'minifigure_name': 'CARA DUNE'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e616'),
#  'class_id': 13,
#  'lego_id': '75254',
#  'lego_name': 'AT-ST Raider from The Mandalorian',
#  'minifigure_name': 'KLATOOINIAN RAIDER 1'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e617'),
#  'class_id': 14,
#  'lego_id': '75254',
#  'lego_name': 'AT-ST Raider from The Mandalorian',
#  'minifigure_name': 'KLATOOINIAN RAIDER 2'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e618'),
#  'class_id': 15,
#  'lego_id': '76128',
#  'lego_name': 'Molten Man Battle',
#  'minifigure_name': 'MYSTERIO'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e619'),
#  'class_id': 16,
#  'lego_id': '76128',
#  'lego_name': 'Molten Man Battle',
#  'minifigure_name': 'FIREFIGHTER'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e61a'),
#  'class_id': 17,
#  'lego_id': '76128',
#  'lego_name': 'Molten Man Battle',
#  'minifigure_name': 'SPIDER-MAN'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e61b'),
#  'class_id': 18,
#  'lego_id': '75950',
#  'lego_name': 'Aragogs Lair',
#  'minifigure_name': 'Harry Potter'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e61c'),
#  'class_id': 19,
#  'lego_id': '75950',
#  'lego_name': 'Aragogs Lair',
#  'minifigure_name': 'Ron Weasley'}

# %%
for image in legoIMG.find({}):
    pprint.pprint(image)
# Out:
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e61d'),
#  'class_id': 1,
#  'image_id': 0,
#  'image_path': 'resources/marvel/0001/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e61e'),
#  'class_id': 1,
#  'image_id': 1,
#  'image_path': 'resources/marvel/0001/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e61f'),
#  'class_id': 1,
#  'image_id': 2,
#  'image_path': 'resources/marvel/0001/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e620'),
#  'class_id': 1,
#  'image_id': 3,
#  'image_path': 'resources/marvel/0001/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e621'),
#  'class_id': 1,
#  'image_id': 4,
#  'image_path': 'resources/marvel/0001/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e622'),
#  'class_id': 1,
#  'image_id': 5,
#  'image_path': 'resources/marvel/0001/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e623'),
#  'class_id': 1,
#  'image_id': 6,
#  'image_path': 'resources/marvel/0001/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e624'),
#  'class_id': 1,
#  'image_id': 7,
#  'image_path': 'resources/marvel/0001/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e625'),
#  'class_id': 1,
#  'image_id': 8,
#  'image_path': 'resources/marvel/0001/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e626'),
#  'class_id': 1,
#  'image_id': 9,
#  'image_path': 'resources/marvel/0001/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e627'),
#  'class_id': 2,
#  'image_id': 10,
#  'image_path': 'resources/marvel/0002/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e628'),
#  'class_id': 2,
#  'image_id': 11,
#  'image_path': 'resources/marvel/0002/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e629'),
#  'class_id': 2,
#  'image_id': 12,
#  'image_path': 'resources/marvel/0002/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e62a'),
#  'class_id': 2,
#  'image_id': 13,
#  'image_path': 'resources/marvel/0002/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e62b'),
#  'class_id': 2,
#  'image_id': 14,
#  'image_path': 'resources/marvel/0002/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e62c'),
#  'class_id': 2,
#  'image_id': 15,
#  'image_path': 'resources/marvel/0002/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e62d'),
#  'class_id': 2,
#  'image_id': 16,
#  'image_path': 'resources/marvel/0002/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e62e'),
#  'class_id': 2,
#  'image_id': 17,
#  'image_path': 'resources/marvel/0002/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e62f'),
#  'class_id': 2,
#  'image_id': 18,
#  'image_path': 'resources/marvel/0002/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e630'),
#  'class_id': 2,
#  'image_id': 19,
#  'image_path': 'resources/marvel/0002/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e631'),
#  'class_id': 3,
#  'image_id': 20,
#  'image_path': 'resources/marvel/0003/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e632'),
#  'class_id': 3,
#  'image_id': 21,
#  'image_path': 'resources/marvel/0003/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e633'),
#  'class_id': 3,
#  'image_id': 22,
#  'image_path': 'resources/marvel/0003/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e634'),
#  'class_id': 3,
#  'image_id': 23,
#  'image_path': 'resources/marvel/0003/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e635'),
#  'class_id': 3,
#  'image_id': 24,
#  'image_path': 'resources/marvel/0003/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e636'),
#  'class_id': 3,
#  'image_id': 25,
#  'image_path': 'resources/marvel/0003/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e637'),
#  'class_id': 3,
#  'image_id': 26,
#  'image_path': 'resources/marvel/0003/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e638'),
#  'class_id': 3,
#  'image_id': 27,
#  'image_path': 'resources/marvel/0003/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e639'),
#  'class_id': 3,
#  'image_id': 28,
#  'image_path': 'resources/marvel/0003/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e63a'),
#  'class_id': 3,
#  'image_id': 29,
#  'image_path': 'resources/marvel/0003/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e63b'),
#  'class_id': 4,
#  'image_id': 30,
#  'image_path': 'resources/marvel/0004/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e63c'),
#  'class_id': 4,
#  'image_id': 31,
#  'image_path': 'resources/marvel/0004/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e63d'),
#  'class_id': 4,
#  'image_id': 32,
#  'image_path': 'resources/marvel/0004/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e63e'),
#  'class_id': 4,
#  'image_id': 33,
#  'image_path': 'resources/marvel/0004/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e63f'),
#  'class_id': 4,
#  'image_id': 34,
#  'image_path': 'resources/marvel/0004/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e640'),
#  'class_id': 4,
#  'image_id': 35,
#  'image_path': 'resources/marvel/0004/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e641'),
#  'class_id': 4,
#  'image_id': 36,
#  'image_path': 'resources/marvel/0004/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e642'),
#  'class_id': 4,
#  'image_id': 37,
#  'image_path': 'resources/marvel/0004/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e643'),
#  'class_id': 4,
#  'image_id': 38,
#  'image_path': 'resources/marvel/0004/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e644'),
#  'class_id': 4,
#  'image_id': 39,
#  'image_path': 'resources/marvel/0004/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e645'),
#  'class_id': 5,
#  'image_id': 40,
#  'image_path': 'resources/star-wars/0001/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e646'),
#  'class_id': 5,
#  'image_id': 41,
#  'image_path': 'resources/star-wars/0001/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e647'),
#  'class_id': 5,
#  'image_id': 42,
#  'image_path': 'resources/star-wars/0001/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e648'),
#  'class_id': 5,
#  'image_id': 43,
#  'image_path': 'resources/star-wars/0001/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e649'),
#  'class_id': 5,
#  'image_id': 44,
#  'image_path': 'resources/star-wars/0001/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e64a'),
#  'class_id': 5,
#  'image_id': 45,
#  'image_path': 'resources/star-wars/0001/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e64b'),
#  'class_id': 5,
#  'image_id': 46,
#  'image_path': 'resources/star-wars/0001/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e64c'),
#  'class_id': 5,
#  'image_id': 47,
#  'image_path': 'resources/star-wars/0001/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e64d'),
#  'class_id': 5,
#  'image_id': 48,
#  'image_path': 'resources/star-wars/0001/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e64e'),
#  'class_id': 5,
#  'image_id': 49,
#  'image_path': 'resources/star-wars/0001/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e64f'),
#  'class_id': 5,
#  'image_id': 50,
#  'image_path': 'resources/star-wars/0001/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e650'),
#  'class_id': 6,
#  'image_id': 51,
#  'image_path': 'resources/star-wars/0002/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e651'),
#  'class_id': 6,
#  'image_id': 52,
#  'image_path': 'resources/star-wars/0002/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e652'),
#  'class_id': 6,
#  'image_id': 53,
#  'image_path': 'resources/star-wars/0002/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e653'),
#  'class_id': 6,
#  'image_id': 54,
#  'image_path': 'resources/star-wars/0002/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e654'),
#  'class_id': 6,
#  'image_id': 55,
#  'image_path': 'resources/star-wars/0002/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e655'),
#  'class_id': 6,
#  'image_id': 56,
#  'image_path': 'resources/star-wars/0002/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e656'),
#  'class_id': 6,
#  'image_id': 57,
#  'image_path': 'resources/star-wars/0002/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e657'),
#  'class_id': 6,
#  'image_id': 58,
#  'image_path': 'resources/star-wars/0002/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e658'),
#  'class_id': 6,
#  'image_id': 59,
#  'image_path': 'resources/star-wars/0002/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e659'),
#  'class_id': 6,
#  'image_id': 60,
#  'image_path': 'resources/star-wars/0002/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e65a'),
#  'class_id': 6,
#  'image_id': 61,
#  'image_path': 'resources/star-wars/0002/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e65b'),
#  'class_id': 7,
#  'image_id': 62,
#  'image_path': 'resources/star-wars/0003/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e65c'),
#  'class_id': 7,
#  'image_id': 63,
#  'image_path': 'resources/star-wars/0003/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e65d'),
#  'class_id': 7,
#  'image_id': 64,
#  'image_path': 'resources/star-wars/0003/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e65e'),
#  'class_id': 7,
#  'image_id': 65,
#  'image_path': 'resources/star-wars/0003/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e65f'),
#  'class_id': 7,
#  'image_id': 66,
#  'image_path': 'resources/star-wars/0003/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e660'),
#  'class_id': 7,
#  'image_id': 67,
#  'image_path': 'resources/star-wars/0003/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e661'),
#  'class_id': 7,
#  'image_id': 68,
#  'image_path': 'resources/star-wars/0003/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e662'),
#  'class_id': 7,
#  'image_id': 69,
#  'image_path': 'resources/star-wars/0003/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e663'),
#  'class_id': 7,
#  'image_id': 70,
#  'image_path': 'resources/star-wars/0003/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e664'),
#  'class_id': 7,
#  'image_id': 71,
#  'image_path': 'resources/star-wars/0003/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e665'),
#  'class_id': 7,
#  'image_id': 72,
#  'image_path': 'resources/star-wars/0003/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e666'),
#  'class_id': 8,
#  'image_id': 73,
#  'image_path': 'resources/star-wars/0004/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e667'),
#  'class_id': 8,
#  'image_id': 74,
#  'image_path': 'resources/star-wars/0004/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e668'),
#  'class_id': 8,
#  'image_id': 75,
#  'image_path': 'resources/star-wars/0004/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e669'),
#  'class_id': 9,
#  'image_id': 76,
#  'image_path': 'resources/star-wars/0005/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e66a'),
#  'class_id': 9,
#  'image_id': 77,
#  'image_path': 'resources/star-wars/0005/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e66b'),
#  'class_id': 9,
#  'image_id': 78,
#  'image_path': 'resources/star-wars/0005/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e66c'),
#  'class_id': 5,
#  'image_id': 79,
#  'image_path': 'resources/star-wars/0001/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e66d'),
#  'class_id': 6,
#  'image_id': 80,
#  'image_path': 'resources/star-wars/0002/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e66e'),
#  'class_id': 7,
#  'image_id': 81,
#  'image_path': 'resources/star-wars/0003/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e66f'),
#  'class_id': 10,
#  'image_id': 82,
#  'image_path': 'resources/star-wars/0006/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e670'),
#  'class_id': 10,
#  'image_id': 83,
#  'image_path': 'resources/star-wars/0006/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e671'),
#  'class_id': 10,
#  'image_id': 84,
#  'image_path': 'resources/star-wars/0006/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e672'),
#  'class_id': 8,
#  'image_id': 85,
#  'image_path': 'resources/star-wars/0004/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e673'),
#  'class_id': 8,
#  'image_id': 86,
#  'image_path': 'resources/star-wars/0004/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e674'),
#  'class_id': 8,
#  'image_id': 87,
#  'image_path': 'resources/star-wars/0004/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e675'),
#  'class_id': 8,
#  'image_id': 88,
#  'image_path': 'resources/star-wars/0004/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e676'),
#  'class_id': 8,
#  'image_id': 89,
#  'image_path': 'resources/star-wars/0004/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e677'),
#  'class_id': 8,
#  'image_id': 90,
#  'image_path': 'resources/star-wars/0004/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e678'),
#  'class_id': 8,
#  'image_id': 91,
#  'image_path': 'resources/star-wars/0004/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e679'),
#  'class_id': 8,
#  'image_id': 92,
#  'image_path': 'resources/star-wars/0004/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e67a'),
#  'class_id': 8,
#  'image_id': 93,
#  'image_path': 'resources/star-wars/0004/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e67b'),
#  'class_id': 8,
#  'image_id': 94,
#  'image_path': 'resources/star-wars/0004/013.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e67c'),
#  'class_id': 9,
#  'image_id': 95,
#  'image_path': 'resources/star-wars/0005/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e67d'),
#  'class_id': 9,
#  'image_id': 96,
#  'image_path': 'resources/star-wars/0005/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e67e'),
#  'class_id': 9,
#  'image_id': 97,
#  'image_path': 'resources/star-wars/0005/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e67f'),
#  'class_id': 9,
#  'image_id': 98,
#  'image_path': 'resources/star-wars/0005/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e680'),
#  'class_id': 9,
#  'image_id': 99,
#  'image_path': 'resources/star-wars/0005/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e681'),
#  'class_id': 9,
#  'image_id': 100,
#  'image_path': 'resources/star-wars/0005/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e682'),
#  'class_id': 9,
#  'image_id': 101,
#  'image_path': 'resources/star-wars/0005/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e683'),
#  'class_id': 9,
#  'image_id': 102,
#  'image_path': 'resources/star-wars/0005/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e684'),
#  'class_id': 9,
#  'image_id': 103,
#  'image_path': 'resources/star-wars/0005/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e685'),
#  'class_id': 9,
#  'image_id': 104,
#  'image_path': 'resources/star-wars/0005/013.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e686'),
#  'class_id': 9,
#  'image_id': 105,
#  'image_path': 'resources/star-wars/0005/014.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e687'),
#  'class_id': 10,
#  'image_id': 106,
#  'image_path': 'resources/star-wars/0006/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e688'),
#  'class_id': 10,
#  'image_id': 107,
#  'image_path': 'resources/star-wars/0006/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e689'),
#  'class_id': 10,
#  'image_id': 108,
#  'image_path': 'resources/star-wars/0006/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e68a'),
#  'class_id': 10,
#  'image_id': 109,
#  'image_path': 'resources/star-wars/0006/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e68b'),
#  'class_id': 10,
#  'image_id': 110,
#  'image_path': 'resources/star-wars/0006/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e68c'),
#  'class_id': 10,
#  'image_id': 111,
#  'image_path': 'resources/star-wars/0006/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e68d'),
#  'class_id': 10,
#  'image_id': 112,
#  'image_path': 'resources/star-wars/0006/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e68e'),
#  'class_id': 11,
#  'image_id': 113,
#  'image_path': 'resources/star-wars/0007/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e68f'),
#  'class_id': 11,
#  'image_id': 114,
#  'image_path': 'resources/star-wars/0007/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e690'),
#  'class_id': 11,
#  'image_id': 115,
#  'image_path': 'resources/star-wars/0007/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e691'),
#  'class_id': 11,
#  'image_id': 116,
#  'image_path': 'resources/star-wars/0007/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e692'),
#  'class_id': 11,
#  'image_id': 117,
#  'image_path': 'resources/star-wars/0007/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e693'),
#  'class_id': 11,
#  'image_id': 118,
#  'image_path': 'resources/star-wars/0007/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e694'),
#  'class_id': 11,
#  'image_id': 119,
#  'image_path': 'resources/star-wars/0007/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e695'),
#  'class_id': 12,
#  'image_id': 120,
#  'image_path': 'resources/star-wars/0008/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e696'),
#  'class_id': 12,
#  'image_id': 121,
#  'image_path': 'resources/star-wars/0008/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e697'),
#  'class_id': 12,
#  'image_id': 122,
#  'image_path': 'resources/star-wars/0008/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e698'),
#  'class_id': 12,
#  'image_id': 123,
#  'image_path': 'resources/star-wars/0008/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e699'),
#  'class_id': 12,
#  'image_id': 124,
#  'image_path': 'resources/star-wars/0008/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e69a'),
#  'class_id': 12,
#  'image_id': 125,
#  'image_path': 'resources/star-wars/0008/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e69b'),
#  'class_id': 12,
#  'image_id': 126,
#  'image_path': 'resources/star-wars/0008/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e69c'),
#  'class_id': 13,
#  'image_id': 127,
#  'image_path': 'resources/star-wars/0009/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e69d'),
#  'class_id': 13,
#  'image_id': 128,
#  'image_path': 'resources/star-wars/0009/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e69e'),
#  'class_id': 13,
#  'image_id': 129,
#  'image_path': 'resources/star-wars/0009/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e69f'),
#  'class_id': 13,
#  'image_id': 130,
#  'image_path': 'resources/star-wars/0009/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a0'),
#  'class_id': 13,
#  'image_id': 131,
#  'image_path': 'resources/star-wars/0009/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a1'),
#  'class_id': 13,
#  'image_id': 132,
#  'image_path': 'resources/star-wars/0009/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a2'),
#  'class_id': 13,
#  'image_id': 133,
#  'image_path': 'resources/star-wars/0009/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a3'),
#  'class_id': 14,
#  'image_id': 134,
#  'image_path': 'resources/star-wars/0010/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a4'),
#  'class_id': 14,
#  'image_id': 135,
#  'image_path': 'resources/star-wars/0010/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a5'),
#  'class_id': 14,
#  'image_id': 136,
#  'image_path': 'resources/star-wars/0010/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a6'),
#  'class_id': 14,
#  'image_id': 137,
#  'image_path': 'resources/star-wars/0010/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a7'),
#  'class_id': 14,
#  'image_id': 138,
#  'image_path': 'resources/star-wars/0010/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a8'),
#  'class_id': 14,
#  'image_id': 139,
#  'image_path': 'resources/star-wars/0010/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6a9'),
#  'class_id': 14,
#  'image_id': 140,
#  'image_path': 'resources/star-wars/0010/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6aa'),
#  'class_id': 11,
#  'image_id': 141,
#  'image_path': 'resources/star-wars/0007/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ab'),
#  'class_id': 12,
#  'image_id': 142,
#  'image_path': 'resources/star-wars/0008/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ac'),
#  'class_id': 13,
#  'image_id': 143,
#  'image_path': 'resources/star-wars/0009/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ad'),
#  'class_id': 14,
#  'image_id': 144,
#  'image_path': 'resources/star-wars/0010/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ae'),
#  'class_id': 15,
#  'image_id': 145,
#  'image_path': 'resources/marvel/0005/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6af'),
#  'class_id': 15,
#  'image_id': 146,
#  'image_path': 'resources/marvel/0005/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b0'),
#  'class_id': 15,
#  'image_id': 147,
#  'image_path': 'resources/marvel/0005/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b1'),
#  'class_id': 15,
#  'image_id': 148,
#  'image_path': 'resources/marvel/0005/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b2'),
#  'class_id': 15,
#  'image_id': 149,
#  'image_path': 'resources/marvel/0005/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b3'),
#  'class_id': 15,
#  'image_id': 150,
#  'image_path': 'resources/marvel/0005/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b4'),
#  'class_id': 15,
#  'image_id': 151,
#  'image_path': 'resources/marvel/0005/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b5'),
#  'class_id': 15,
#  'image_id': 152,
#  'image_path': 'resources/marvel/0005/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b6'),
#  'class_id': 15,
#  'image_id': 153,
#  'image_path': 'resources/marvel/0005/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b7'),
#  'class_id': 16,
#  'image_id': 154,
#  'image_path': 'resources/marvel/0006/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b8'),
#  'class_id': 16,
#  'image_id': 155,
#  'image_path': 'resources/marvel/0006/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6b9'),
#  'class_id': 16,
#  'image_id': 156,
#  'image_path': 'resources/marvel/0006/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ba'),
#  'class_id': 16,
#  'image_id': 157,
#  'image_path': 'resources/marvel/0006/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6bb'),
#  'class_id': 16,
#  'image_id': 158,
#  'image_path': 'resources/marvel/0006/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6bc'),
#  'class_id': 16,
#  'image_id': 159,
#  'image_path': 'resources/marvel/0006/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6bd'),
#  'class_id': 16,
#  'image_id': 160,
#  'image_path': 'resources/marvel/0006/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6be'),
#  'class_id': 16,
#  'image_id': 161,
#  'image_path': 'resources/marvel/0006/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6bf'),
#  'class_id': 16,
#  'image_id': 162,
#  'image_path': 'resources/marvel/0006/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c0'),
#  'class_id': 17,
#  'image_id': 163,
#  'image_path': 'resources/marvel/0007/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c1'),
#  'class_id': 17,
#  'image_id': 164,
#  'image_path': 'resources/marvel/0007/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c2'),
#  'class_id': 17,
#  'image_id': 165,
#  'image_path': 'resources/marvel/0007/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c3'),
#  'class_id': 17,
#  'image_id': 166,
#  'image_path': 'resources/marvel/0007/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c4'),
#  'class_id': 17,
#  'image_id': 167,
#  'image_path': 'resources/marvel/0007/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c5'),
#  'class_id': 17,
#  'image_id': 168,
#  'image_path': 'resources/marvel/0007/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c6'),
#  'class_id': 17,
#  'image_id': 169,
#  'image_path': 'resources/marvel/0007/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c7'),
#  'class_id': 17,
#  'image_id': 170,
#  'image_path': 'resources/marvel/0007/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c8'),
#  'class_id': 17,
#  'image_id': 171,
#  'image_path': 'resources/marvel/0007/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6c9'),
#  'class_id': 18,
#  'image_id': 172,
#  'image_path': 'resources/harry-potter/0001/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ca'),
#  'class_id': 18,
#  'image_id': 173,
#  'image_path': 'resources/harry-potter/0001/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6cb'),
#  'class_id': 18,
#  'image_id': 174,
#  'image_path': 'resources/harry-potter/0001/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6cc'),
#  'class_id': 18,
#  'image_id': 175,
#  'image_path': 'resources/harry-potter/0001/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6cd'),
#  'class_id': 18,
#  'image_id': 176,
#  'image_path': 'resources/harry-potter/0001/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6ce'),
#  'class_id': 18,
#  'image_id': 177,
#  'image_path': 'resources/harry-potter/0001/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6cf'),
#  'class_id': 18,
#  'image_id': 178,
#  'image_path': 'resources/harry-potter/0001/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d0'),
#  'class_id': 18,
#  'image_id': 179,
#  'image_path': 'resources/harry-potter/0001/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d1'),
#  'class_id': 18,
#  'image_id': 180,
#  'image_path': 'resources/harry-potter/0001/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d2'),
#  'class_id': 18,
#  'image_id': 181,
#  'image_path': 'resources/harry-potter/0001/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d3'),
#  'class_id': 18,
#  'image_id': 182,
#  'image_path': 'resources/harry-potter/0001/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d4'),
#  'class_id': 18,
#  'image_id': 183,
#  'image_path': 'resources/harry-potter/0001/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d5'),
#  'class_id': 18,
#  'image_id': 184,
#  'image_path': 'resources/harry-potter/0001/013.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d6'),
#  'class_id': 19,
#  'image_id': 185,
#  'image_path': 'resources/harry-potter/0002/001.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d7'),
#  'class_id': 19,
#  'image_id': 186,
#  'image_path': 'resources/harry-potter/0002/002.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d8'),
#  'class_id': 19,
#  'image_id': 187,
#  'image_path': 'resources/harry-potter/0002/003.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6d9'),
#  'class_id': 19,
#  'image_id': 188,
#  'image_path': 'resources/harry-potter/0002/004.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6da'),
#  'class_id': 19,
#  'image_id': 189,
#  'image_path': 'resources/harry-potter/0002/005.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6db'),
#  'class_id': 19,
#  'image_id': 190,
#  'image_path': 'resources/harry-potter/0002/006.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6dc'),
#  'class_id': 19,
#  'image_id': 191,
#  'image_path': 'resources/harry-potter/0002/007.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6dd'),
#  'class_id': 19,
#  'image_id': 192,
#  'image_path': 'resources/harry-potter/0002/008.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6de'),
#  'class_id': 19,
#  'image_id': 193,
#  'image_path': 'resources/harry-potter/0002/009.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6df'),
#  'class_id': 19,
#  'image_id': 194,
#  'image_path': 'resources/harry-potter/0002/010.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6e0'),
#  'class_id': 19,
#  'image_id': 195,
#  'image_path': 'resources/harry-potter/0002/011.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6e1'),
#  'class_id': 19,
#  'image_id': 196,
#  'image_path': 'resources/harry-potter/0002/012.jpg'}
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e6e2'),
#  'class_id': 19,
#  'image_id': 197,
#  'image_path': 'resources/harry-potter/0002/013.jpg'}

# %%
for i in legoCT.find({'minifigure_name': 'YODA'}):
    pprint.pprint(i)
# Out:
# {'_id': ObjectId('5f5bc2bf1f36c3cec291e60e'),
#  'class_id': 5,
#  'lego_id': '75208',
#  'lego_name': 'Yodas Hut',
#  'minifigure_name': 'YODA'}

# %%
for image in legoIMG.find({'class_id': 5}):
    img=mpimg.imread(image["image_path"]) 
    imgplot = plt.imshow(img) 
    plt.show()
